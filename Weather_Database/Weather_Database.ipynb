# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
import time
from citipy import citipy

import os, sys
currentdir = os.path.dirname(os.path.realpath("Weather_Database"))
parentdir = os.path.dirname(currentdir)
sys.path.append(parentdir)
# Import API key
from config import weather_api_key

# Import linregress
from scipy.stats import linregress
import textwrap

# %%
#create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-89.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descrip,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | padang
# Processing Record 8 of Set 1 | mirassol
# Processing Record 9 of Set 1 | touros
# Processing Record 10 of Set 1 | mana
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | sao felix do xingu
# Processing Record 15 of Set 1 | krasnoselkup
# Processing Record 16 of Set 1 | yurga
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | nampula
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | berdyuzhye
# City not found. Skipping...
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | khokhlovo
# Processing Record 26 of Set 1 | narsaq
# Processing Record 27 of Set 1 | berlevag
# Processing Record 28 of Set 1 | isiro
# Processing Record 29 of Set 1 | lobito
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | inhambane
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | vytegra
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | aquiraz
# Processing Record 42 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 1 | stornoway
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | bubaque
# Processing Record 3 of Set 2 | klaksvik
# Processing Record 4 of Set 2 | haines junction
# Processing Record 5 of Set 2 | severo-kurilsk
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | leningradskiy
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | baherden
# Processing Record 12 of Set 2 | aykhal
# Processing Record 13 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 2 | victoria
# Processing Record 15 of Set 2 | ulladulla
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | lavumisa
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | rodrigues alves
# Processing Record 20 of Set 2 | brazzaville
# Processing Record 21 of Set 2 | teguise
# Processing Record 22 of Set 2 | guajara-mirim
# City not found. Skipping...
# Processing Record 23 of Set 2 | panguna
# Processing Record 24 of Set 2 | coahuayana
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | isetskoye
# Processing Record 28 of Set 2 | dalvik
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | taoudenni
# Processing Record 31 of Set 2 | humberto de campos
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | jalu
# Processing Record 36 of Set 2 | xifeng
# Processing Record 37 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | vanino
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | tarsus
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | praia da vitoria
# Processing Record 44 of Set 2 | assiniboia
# Processing Record 45 of Set 2 | camana
# Processing Record 46 of Set 2 | hilo
# Processing Record 47 of Set 2 | isagarh
# Processing Record 48 of Set 2 | namibe
# Processing Record 49 of Set 2 | kisangani
# Processing Record 50 of Set 2 | barguzin
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | buyabod
# Processing Record 3 of Set 3 | kharp
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | sao filipe
# Processing Record 7 of Set 3 | escanaba
# Processing Record 8 of Set 3 | lai
# Processing Record 9 of Set 3 | hope mills
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | salisbury
# Processing Record 12 of Set 3 | highland springs
# Processing Record 13 of Set 3 | caravelas
# Processing Record 14 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 3 | baculin
# Processing Record 16 of Set 3 | ormara
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | sertanopolis
# Processing Record 19 of Set 3 | la macarena
# Processing Record 20 of Set 3 | edgewater
# Processing Record 21 of Set 3 | praia
# Processing Record 22 of Set 3 | faya
# Processing Record 23 of Set 3 | gat
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | borlange
# City not found. Skipping...
# Processing Record 27 of Set 3 | massakory
# Processing Record 28 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 3 | itarema
# Processing Record 30 of Set 3 | fortuna
# Processing Record 31 of Set 3 | morant bay
# Processing Record 32 of Set 3 | omboue
# Processing Record 33 of Set 3 | liverpool
# Processing Record 34 of Set 3 | sistranda
# Processing Record 35 of Set 3 | poplar bluff
# Processing Record 36 of Set 3 | vaini
# Processing Record 37 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 3 | buchanan
# Processing Record 39 of Set 3 | saint-francois
# Processing Record 40 of Set 3 | umm kaddadah
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | nanortalik
# Processing Record 43 of Set 3 | iqaluit
# Processing Record 44 of Set 3 | harper
# Processing Record 45 of Set 3 | terrace
# Processing Record 46 of Set 3 | altamont
# Processing Record 47 of Set 3 | lompoc
# Processing Record 48 of Set 3 | stip
# City not found. Skipping...
# Processing Record 49 of Set 3 | terenga
# City not found. Skipping...
# Processing Record 50 of Set 3 | abha
# Processing Record 1 of Set 4 | mount gambier
# Processing Record 2 of Set 4 | hithadhoo
# Processing Record 3 of Set 4 | paamiut
# Processing Record 4 of Set 4 | barrow
# Processing Record 5 of Set 4 | qaanaaq
# Processing Record 6 of Set 4 | tessalit
# Processing Record 7 of Set 4 | shunyi
# Processing Record 8 of Set 4 | bambous virieux
# Processing Record 9 of Set 4 | atambua
# Processing Record 10 of Set 4 | khalkhal
# Processing Record 11 of Set 4 | paka
# Processing Record 12 of Set 4 | komatipoort
# Processing Record 13 of Set 4 | yaan
# Processing Record 14 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 4 | cherskiy
# Processing Record 16 of Set 4 | anqing
# Processing Record 17 of Set 4 | tete
# Processing Record 18 of Set 4 | springbok
# Processing Record 19 of Set 4 | acarau
# Processing Record 20 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 4 | bambanglipuro
# Processing Record 22 of Set 4 | koulikoro
# Processing Record 23 of Set 4 | grindavik
# Processing Record 24 of Set 4 | port-cartier
# Processing Record 25 of Set 4 | sault sainte marie
# Processing Record 26 of Set 4 | ostersund
# Processing Record 27 of Set 4 | cayenne
# Processing Record 28 of Set 4 | korogwe
# City not found. Skipping...
# Processing Record 29 of Set 4 | newport
# Processing Record 30 of Set 4 | hambantota
# Processing Record 31 of Set 4 | hasaki
# Processing Record 32 of Set 4 | sibolga
# Processing Record 33 of Set 4 | normandin
# Processing Record 34 of Set 4 | malanje
# Processing Record 35 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 4 | havre-saint-pierre
# Processing Record 37 of Set 4 | meulaboh
# Processing Record 38 of Set 4 | songea
# Processing Record 39 of Set 4 | bengkulu
# Processing Record 40 of Set 4 | pauini
# Processing Record 41 of Set 4 | vardo
# Processing Record 42 of Set 4 | kendari
# Processing Record 43 of Set 4 | orbetello
# Processing Record 44 of Set 4 | luceville
# City not found. Skipping...
# Processing Record 45 of Set 4 | ancud
# Processing Record 46 of Set 4 | hamilton
# Processing Record 47 of Set 4 | akyab
# Processing Record 48 of Set 4 | kavieng
# Processing Record 49 of Set 4 | saucillo
# Processing Record 50 of Set 4 | rawson
# Processing Record 1 of Set 5 | singaraja
# Processing Record 2 of Set 5 | koutiala
# Processing Record 3 of Set 5 | otopeni
# Processing Record 4 of Set 5 | aksarka
# Processing Record 5 of Set 5 | kavaratti
# Processing Record 6 of Set 5 | salinas
# Processing Record 7 of Set 5 | alice springs
# Processing Record 8 of Set 5 | avarua
# Processing Record 9 of Set 5 | saint george
# Processing Record 10 of Set 5 | sitka
# Processing Record 11 of Set 5 | tuatapere
# Processing Record 12 of Set 5 | namatanai
# Processing Record 13 of Set 5 | coihaique
# Processing Record 14 of Set 5 | chanika
# Processing Record 15 of Set 5 | puerto narino
# Processing Record 16 of Set 5 | san isidro
# Processing Record 17 of Set 5 | puerto escondido
# Processing Record 18 of Set 5 | khatanga
# Processing Record 19 of Set 5 | talnakh
# Processing Record 20 of Set 5 | koson
# Processing Record 21 of Set 5 | grand junction
# Processing Record 22 of Set 5 | auki
# Processing Record 23 of Set 5 | mehamn
# Processing Record 24 of Set 5 | ikole
# City not found. Skipping...
# Processing Record 25 of Set 5 | kroderen
# City not found. Skipping...
# Processing Record 26 of Set 5 | zyryanka
# Processing Record 27 of Set 5 | las vegas
# Processing Record 28 of Set 5 | fairbanks
# Processing Record 29 of Set 5 | airai
# Processing Record 30 of Set 5 | gobo
# Processing Record 31 of Set 5 | buala
# Processing Record 32 of Set 5 | ashqelon
# Processing Record 33 of Set 5 | katsuura
# Processing Record 34 of Set 5 | grand gaube
# Processing Record 35 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 5 | kloulklubed
# Processing Record 37 of Set 5 | college
# Processing Record 38 of Set 5 | arroio grande
# Processing Record 39 of Set 5 | shimoda
# Processing Record 40 of Set 5 | nome
# Processing Record 41 of Set 5 | alihe
# Processing Record 42 of Set 5 | tatishchevo
# Processing Record 43 of Set 5 | verkhnevilyuysk
# Processing Record 44 of Set 5 | yeppoon
# Processing Record 45 of Set 5 | opuwo
# Processing Record 46 of Set 5 | vadso
# Processing Record 47 of Set 5 | xining
# Processing Record 48 of Set 5 | bandarbeyla
# Processing Record 49 of Set 5 | piacabucu
# Processing Record 50 of Set 5 | sao mateus do maranhao
# Processing Record 1 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 6 | yagodnoye
# Processing Record 3 of Set 6 | hualmay
# Processing Record 4 of Set 6 | dzhuryn
# Processing Record 5 of Set 6 | dali
# Processing Record 6 of Set 6 | kamaishi
# Processing Record 7 of Set 6 | tuktoyaktuk
# Processing Record 8 of Set 6 | lavrentiya
# Processing Record 9 of Set 6 | carnarvon
# Processing Record 10 of Set 6 | santa cruz
# Processing Record 11 of Set 6 | komsomolskiy
# Processing Record 12 of Set 6 | haikou
# Processing Record 13 of Set 6 | louis trichardt
# Processing Record 14 of Set 6 | durango
# Processing Record 15 of Set 6 | henzada
# City not found. Skipping...
# Processing Record 16 of Set 6 | balkanabat
# Processing Record 17 of Set 6 | bulgan
# Processing Record 18 of Set 6 | kalga
# Processing Record 19 of Set 6 | jequitinhonha
# Processing Record 20 of Set 6 | tuxpan
# Processing Record 21 of Set 6 | najran
# Processing Record 22 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 6 | mogadishu
# Processing Record 24 of Set 6 | vila velha
# Processing Record 25 of Set 6 | vestmannaeyjar
# Processing Record 26 of Set 6 | neyshabur
# Processing Record 27 of Set 6 | guerrero negro
# Processing Record 28 of Set 6 | ugoofaaru
# Processing Record 29 of Set 6 | eyrarbakki
# Processing Record 30 of Set 6 | male
# Processing Record 31 of Set 6 | pisco
# Processing Record 32 of Set 6 | montepuez
# Processing Record 33 of Set 6 | vysokogornyy
# Processing Record 34 of Set 6 | yar-sale
# Processing Record 35 of Set 6 | rundu
# Processing Record 36 of Set 6 | sabha
# Processing Record 37 of Set 6 | adrar
# Processing Record 38 of Set 6 | asau
# Processing Record 39 of Set 6 | ponta do sol
# Processing Record 40 of Set 6 | hanstholm
# Processing Record 41 of Set 6 | mantua
# Processing Record 42 of Set 6 | zvecka
# Processing Record 43 of Set 6 | san quintin
# Processing Record 44 of Set 6 | avera
# Processing Record 45 of Set 6 | bimbo
# Processing Record 46 of Set 6 | hayato
# City not found. Skipping...
# Processing Record 47 of Set 6 | pangnirtung
# Processing Record 48 of Set 6 | shenjiamen
# Processing Record 49 of Set 6 | tomatlan
# Processing Record 50 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 7 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 2 of Set 7 | ciudad bolivar
# Processing Record 3 of Set 7 | birao
# Processing Record 4 of Set 7 | ornskoldsvik
# Processing Record 5 of Set 7 | ponnani
# Processing Record 6 of Set 7 | sao raimundo das mangabeiras
# Processing Record 7 of Set 7 | atar
# Processing Record 8 of Set 7 | hobyo
# Processing Record 9 of Set 7 | thinadhoo
# Processing Record 10 of Set 7 | walvis bay
# Processing Record 11 of Set 7 | ilulissat
# Processing Record 12 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 13 of Set 7 | rafai
# Processing Record 14 of Set 7 | san patricio
# Processing Record 15 of Set 7 | aripuana
# Processing Record 16 of Set 7 | takayama
# Processing Record 17 of Set 7 | yulara
# Processing Record 18 of Set 7 | lagoa
# Processing Record 19 of Set 7 | el alto
# Processing Record 20 of Set 7 | beberibe
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | pevek
# Processing Record 23 of Set 7 | hovd
# Processing Record 24 of Set 7 | katangli
# Processing Record 25 of Set 7 | scottsbluff
# Processing Record 26 of Set 7 | lasa
# Processing Record 27 of Set 7 | tenosique
# Processing Record 28 of Set 7 | abeche
# Processing Record 29 of Set 7 | bilibino
# Processing Record 30 of Set 7 | sarakhs
# Processing Record 31 of Set 7 | bathsheba
# Processing Record 32 of Set 7 | saint anthony
# Processing Record 33 of Set 7 | manga
# Processing Record 34 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 35 of Set 7 | zhezkazgan
# Processing Record 36 of Set 7 | ahipara
# Processing Record 37 of Set 7 | camacha
# Processing Record 38 of Set 7 | laela
# Processing Record 39 of Set 7 | baykit
# Processing Record 40 of Set 7 | veraval
# Processing Record 41 of Set 7 | amuntai
# Processing Record 42 of Set 7 | provideniya
# Processing Record 43 of Set 7 | shingu
# Processing Record 44 of Set 7 | constitucion
# Processing Record 45 of Set 7 | taltal
# Processing Record 46 of Set 7 | dubbo
# Processing Record 47 of Set 7 | bangkal
# Processing Record 48 of Set 7 | upernavik
# Processing Record 49 of Set 7 | buta
# Processing Record 50 of Set 7 | turbat
# Processing Record 1 of Set 8 | sayyan
# Processing Record 2 of Set 8 | jiuquan
# Processing Record 3 of Set 8 | xinyang
# Processing Record 4 of Set 8 | chegdomyn
# Processing Record 5 of Set 8 | agadez
# Processing Record 6 of Set 8 | semnan
# Processing Record 7 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 8 | bonavista
# Processing Record 9 of Set 8 | yerbogachen
# Processing Record 10 of Set 8 | tiarei
# Processing Record 11 of Set 8 | qaqortoq
# Processing Record 12 of Set 8 | kaeo
# Processing Record 13 of Set 8 | laguna
# Processing Record 14 of Set 8 | rio gallegos
# Processing Record 15 of Set 8 | marawi
# Processing Record 16 of Set 8 | vila franca do campo
# Processing Record 17 of Set 8 | ustynivka
# Processing Record 18 of Set 8 | sola
# Processing Record 19 of Set 8 | timmins
# Processing Record 20 of Set 8 | rocha
# Processing Record 21 of Set 8 | coaraci
# Processing Record 22 of Set 8 | nador
# Processing Record 23 of Set 8 | khani
# Processing Record 24 of Set 8 | trelew
# Processing Record 25 of Set 8 | rasra
# Processing Record 26 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 27 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 8 | tarakan
# Processing Record 29 of Set 8 | olafsvik
# Processing Record 30 of Set 8 | westonaria
# Processing Record 31 of Set 8 | prince rupert
# Processing Record 32 of Set 8 | malazgirt
# Processing Record 33 of Set 8 | lucapa
# Processing Record 34 of Set 8 | kruisfontein
# Processing Record 35 of Set 8 | santa isabel do rio negro
# Processing Record 36 of Set 8 | manavgat
# Processing Record 37 of Set 8 | noumea
# Processing Record 38 of Set 8 | margate
# Processing Record 39 of Set 8 | coquimbo
# Processing Record 40 of Set 8 | port blair
# Processing Record 41 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 8 | tyumentsevo
# Processing Record 43 of Set 8 | portlethen
# Processing Record 44 of Set 8 | ust-omchug
# Processing Record 45 of Set 8 | mandalgovi
# Processing Record 46 of Set 8 | talara
# Processing Record 47 of Set 8 | aksu
# Processing Record 48 of Set 8 | pontes e lacerda
# Processing Record 49 of Set 8 | geraldton
# Processing Record 50 of Set 8 | mercedes
# Processing Record 1 of Set 9 | nishihara
# Processing Record 2 of Set 9 | grand forks
# Processing Record 3 of Set 9 | salalah
# Processing Record 4 of Set 9 | saint-pierre
# Processing Record 5 of Set 9 | zhanakorgan
# Processing Record 6 of Set 9 | trairi
# Processing Record 7 of Set 9 | soyo
# Processing Record 8 of Set 9 | camalu
# Processing Record 9 of Set 9 | evensk
# Processing Record 10 of Set 9 | achisay
# City not found. Skipping...
# Processing Record 11 of Set 9 | larsnes
# Processing Record 12 of Set 9 | san policarpo
# Processing Record 13 of Set 9 | ahuimanu
# Processing Record 14 of Set 9 | hot springs
# Processing Record 15 of Set 9 | epalinges
# Processing Record 16 of Set 9 | mayo
# Processing Record 17 of Set 9 | tura
# Processing Record 18 of Set 9 | tabas
# Processing Record 19 of Set 9 | sept-iles
# Processing Record 20 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 9 | san cristobal
# Processing Record 22 of Set 9 | dunmore town
# Processing Record 23 of Set 9 | catende
# Processing Record 24 of Set 9 | hodkovice nad mohelkou
# Processing Record 25 of Set 9 | senigallia
# Processing Record 26 of Set 9 | ocos
# Processing Record 27 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 9 | jutai
# Processing Record 29 of Set 9 | graciano sanchez
# Processing Record 30 of Set 9 | san vicente
# Processing Record 31 of Set 9 | arandis
# Processing Record 32 of Set 9 | champerico
# Processing Record 33 of Set 9 | egvekinot
# Processing Record 34 of Set 9 | tacuarembo
# Processing Record 35 of Set 9 | chebsara
# Processing Record 36 of Set 9 | nioro
# Processing Record 37 of Set 9 | vostok
# Processing Record 38 of Set 9 | cabedelo
# Processing Record 39 of Set 9 | valdosta
# Processing Record 40 of Set 9 | hofn
# Processing Record 41 of Set 9 | luba
# Processing Record 42 of Set 9 | goderich
# Processing Record 43 of Set 9 | andenes
# Processing Record 44 of Set 9 | port lincoln
# Processing Record 45 of Set 9 | poum
# Processing Record 46 of Set 9 | kichera
# Processing Record 47 of Set 9 | qasigiannguit
# Processing Record 48 of Set 9 | houma
# Processing Record 49 of Set 9 | myitkyina
# Processing Record 50 of Set 9 | kartaly
# Processing Record 1 of Set 10 | maniwaki
# Processing Record 2 of Set 10 | barkhan
# Processing Record 3 of Set 10 | broadstairs
# Processing Record 4 of Set 10 | richards bay
# Processing Record 5 of Set 10 | raudeberg
# Processing Record 6 of Set 10 | samfya
# Processing Record 7 of Set 10 | jiujiang
# Processing Record 8 of Set 10 | kolokani
# Processing Record 9 of Set 10 | nagato
# Processing Record 10 of Set 10 | puerto madero
# Processing Record 11 of Set 10 | itaqui
# Processing Record 12 of Set 10 | antofagasta
# Processing Record 13 of Set 10 | aligudarz
# Processing Record 14 of Set 10 | komsomolets
# Processing Record 15 of Set 10 | bowen
# Processing Record 16 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 17 of Set 10 | kiama
# Processing Record 18 of Set 10 | trincomalee
# Processing Record 19 of Set 10 | alekseyevka
# Processing Record 20 of Set 10 | maltahohe
# Processing Record 21 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 22 of Set 10 | guantanamo
# Processing Record 23 of Set 10 | ankang
# Processing Record 24 of Set 10 | vilyuysk
# Processing Record 25 of Set 10 | beloha
# Processing Record 26 of Set 10 | lufkin
# Processing Record 27 of Set 10 | arivonimamo
# Processing Record 28 of Set 10 | kingston
# Processing Record 29 of Set 10 | xiongyue
# Processing Record 30 of Set 10 | barranca
# Processing Record 31 of Set 10 | komarno
# Processing Record 32 of Set 10 | sao jose da coroa grande
# Processing Record 33 of Set 10 | pitimbu
# Processing Record 34 of Set 10 | morondava
# Processing Record 35 of Set 10 | chimbote
# Processing Record 36 of Set 10 | saint-ambroise
# Processing Record 37 of Set 10 | cheremkhovo
# Processing Record 38 of Set 10 | kollam
# Processing Record 39 of Set 10 | whakatane
# Processing Record 40 of Set 10 | bumba
# Processing Record 41 of Set 10 | beringovskiy
# Processing Record 42 of Set 10 | half moon bay
# Processing Record 43 of Set 10 | kyshtovka
# Processing Record 44 of Set 10 | broken hill
# Processing Record 45 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 10 | comodoro rivadavia
# Processing Record 47 of Set 10 | kizema
# Processing Record 48 of Set 10 | dongsheng
# Processing Record 49 of Set 10 | bunia
# Processing Record 50 of Set 10 | voznesenye
# Processing Record 1 of Set 11 | korla
# Processing Record 2 of Set 11 | yenagoa
# Processing Record 3 of Set 11 | hirara
# Processing Record 4 of Set 11 | udachnyy
# Processing Record 5 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 6 of Set 11 | port hardy
# Processing Record 7 of Set 11 | carman
# Processing Record 8 of Set 11 | montgomery
# Processing Record 9 of Set 11 | lazaro cardenas
# Processing Record 10 of Set 11 | severo-yeniseyskiy
# Processing Record 11 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 12 of Set 11 | churapcha
# Processing Record 13 of Set 11 | oriximina
# Processing Record 14 of Set 11 | estepa
# Processing Record 15 of Set 11 | san juan
# Processing Record 16 of Set 11 | tashtagol
# Processing Record 17 of Set 11 | sungaipenuh
# Processing Record 18 of Set 11 | tilichiki
# Processing Record 19 of Set 11 | barcelos
# Processing Record 20 of Set 11 | fredericksburg
# Processing Record 21 of Set 11 | samarai
# Processing Record 22 of Set 11 | oktyabrskiy
# Processing Record 23 of Set 11 | zarya
# Processing Record 24 of Set 11 | broome
# Processing Record 25 of Set 11 | gamba
# Processing Record 26 of Set 11 | abreus
# Processing Record 27 of Set 11 | kungurtug
# Processing Record 28 of Set 11 | vagur
# Processing Record 29 of Set 11 | fuling
# Processing Record 30 of Set 11 | batesville
# Processing Record 31 of Set 11 | pakhtakoron
# Processing Record 32 of Set 11 | talcahuano
# Processing Record 33 of Set 11 | wagga wagga
# Processing Record 34 of Set 11 | ust-uda
# Processing Record 35 of Set 11 | jaisalmer
# Processing Record 36 of Set 11 | ishlei
# City not found. Skipping...
# Processing Record 37 of Set 11 | manacapuru
# Processing Record 38 of Set 11 | huilong
# Processing Record 39 of Set 11 | torbay
# Processing Record 40 of Set 11 | pleshanovo
# Processing Record 41 of Set 11 | vao
# Processing Record 42 of Set 11 | port keats
# Processing Record 43 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 11 | strangnas
# Processing Record 45 of Set 11 | kemijarvi
# Processing Record 46 of Set 11 | pangani
# Processing Record 47 of Set 11 | argelia
# Processing Record 48 of Set 11 | biak
# Processing Record 49 of Set 11 | kiunga
# Processing Record 50 of Set 11 | emba
# Processing Record 1 of Set 12 | khor
# Processing Record 2 of Set 12 | varzea da palma
# Processing Record 3 of Set 12 | pueblo
# Processing Record 4 of Set 12 | lata
# Processing Record 5 of Set 12 | nakatsugawa
# Processing Record 6 of Set 12 | eureka
# Processing Record 7 of Set 12 | nantucket
# Processing Record 8 of Set 12 | hun
# Processing Record 9 of Set 12 | klimovo
# Processing Record 10 of Set 12 | ballangen
# Processing Record 11 of Set 12 | russell
# Processing Record 12 of Set 12 | anacortes
# Processing Record 13 of Set 12 | okhotsk
# Processing Record 14 of Set 12 | kasugai
# Processing Record 15 of Set 12 | sorland
# Processing Record 16 of Set 12 | san pedro de uraba
# Processing Record 17 of Set 12 | siyabuswa
# Processing Record 18 of Set 12 | vila
# Processing Record 19 of Set 12 | skelleftea
# Processing Record 20 of Set 12 | roxas
# Processing Record 21 of Set 12 | sangar
# Processing Record 22 of Set 12 | dashitou
# Processing Record 23 of Set 12 | windsor
# Processing Record 24 of Set 12 | makakilo city
# Processing Record 25 of Set 12 | manta
# Processing Record 26 of Set 12 | juquitiba
# Processing Record 27 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 12 | daru
# Processing Record 29 of Set 12 | kleck
# City not found. Skipping...
# Processing Record 30 of Set 12 | palmer
# Processing Record 31 of Set 12 | magadan
# Processing Record 32 of Set 12 | manzhouli
# Processing Record 33 of Set 12 | halifax
# Processing Record 34 of Set 12 | salme
# Processing Record 35 of Set 12 | kaniama
# Processing Record 36 of Set 12 | tiquicheo
# Processing Record 37 of Set 12 | dingle
# Processing Record 38 of Set 12 | atka
# City not found. Skipping...
# Processing Record 39 of Set 12 | les cayes
# Processing Record 40 of Set 12 | kombissiri
# Processing Record 41 of Set 12 | otane
# Processing Record 42 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 43 of Set 12 | christchurch
# Processing Record 44 of Set 12 | zapolyarnyy
# Processing Record 45 of Set 12 | lenger
# Processing Record 46 of Set 12 | kedrovyy
# Processing Record 47 of Set 12 | urucui
# Processing Record 48 of Set 12 | mount pleasant
# Processing Record 49 of Set 12 | port-gentil
# Processing Record 50 of Set 12 | gimbi
# Processing Record 1 of Set 13 | mogapi
# Processing Record 2 of Set 13 | marquette
# Processing Record 3 of Set 13 | la ronge
# Processing Record 4 of Set 13 | sidi ali
# Processing Record 5 of Set 13 | ranong
# Processing Record 6 of Set 13 | cairns
# Processing Record 7 of Set 13 | las palmas
# Processing Record 8 of Set 13 | coulihaut
# City not found. Skipping...
# Processing Record 9 of Set 13 | cao bang
# Processing Record 10 of Set 13 | salamiyah
# Processing Record 11 of Set 13 | price
# Processing Record 12 of Set 13 | makrana
# Processing Record 13 of Set 13 | dutse
# Processing Record 14 of Set 13 | toora-khem
# Processing Record 15 of Set 13 | nagua
# Processing Record 16 of Set 13 | zaragoza
# Processing Record 17 of Set 13 | eyl
# Processing Record 18 of Set 13 | impfondo
# Processing Record 19 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 13 | jalingo
# Processing Record 21 of Set 13 | prerov
# Processing Record 22 of Set 13 | slave lake
# Processing Record 23 of Set 13 | zhanaozen
# Processing Record 24 of Set 13 | platanos
# Processing Record 25 of Set 13 | te anau
# Processing Record 26 of Set 13 | lieksa
# Processing Record 27 of Set 13 | wenling
# Processing Record 28 of Set 13 | eydhafushi
# Processing Record 29 of Set 13 | shizunai
# Processing Record 30 of Set 13 | teya
# Processing Record 31 of Set 13 | sorong
# Processing Record 32 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 13 | konstantinovka
# Processing Record 34 of Set 13 | prainha
# Processing Record 35 of Set 13 | baiao
# Processing Record 36 of Set 13 | talaya
# Processing Record 37 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 13 | uttaradit
# Processing Record 39 of Set 13 | kajaani
# Processing Record 40 of Set 13 | north bend
# Processing Record 41 of Set 13 | yanji
# Processing Record 42 of Set 13 | zachary
# Processing Record 43 of Set 13 | koulamoutou
# Processing Record 44 of Set 13 | mumford
# Processing Record 45 of Set 13 | la asuncion
# Processing Record 46 of Set 13 | omsukchan
# Processing Record 47 of Set 13 | kamina
# Processing Record 48 of Set 13 | porto novo
# Processing Record 49 of Set 13 | bata
# Processing Record 50 of Set 13 | bar harbor
# Processing Record 1 of Set 14 | zyryanovsk
# Processing Record 2 of Set 14 | manzanillo
# Processing Record 3 of Set 14 | sao geraldo do araguaia
# Processing Record 4 of Set 14 | changji
# Processing Record 5 of Set 14 | hervey bay
# Processing Record 6 of Set 14 | nelson bay
# Processing Record 7 of Set 14 | kavaje
# Processing Record 8 of Set 14 | biloela
# Processing Record 9 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 10 of Set 14 | madaoua
# Processing Record 11 of Set 14 | camargo
# Processing Record 12 of Set 14 | santa vitoria
# Processing Record 13 of Set 14 | sakyla
# Processing Record 14 of Set 14 | dukat
# Processing Record 15 of Set 14 | waitati
# Processing Record 16 of Set 14 | barrhead
# Processing Record 17 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 14 | angoche
# Processing Record 19 of Set 14 | asosa
# Processing Record 20 of Set 14 | antonina
# Processing Record 21 of Set 14 | kumano
# Processing Record 22 of Set 14 | floriano
# Processing Record 23 of Set 14 | issa
# Processing Record 24 of Set 14 | sao joao da barra
# Processing Record 25 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 14 | parambu
# Processing Record 27 of Set 14 | baghdad
# Processing Record 28 of Set 14 | batemans bay
# Processing Record 29 of Set 14 | qui nhon
# Processing Record 30 of Set 14 | shakawe
# Processing Record 31 of Set 14 | ati
# Processing Record 32 of Set 14 | turayf
# Processing Record 33 of Set 14 | bergen
# Processing Record 34 of Set 14 | klyuchi
# Processing Record 35 of Set 14 | waipawa
# Processing Record 36 of Set 14 | mouila
# Processing Record 37 of Set 14 | luwuk
# Processing Record 38 of Set 14 | havelock
# Processing Record 39 of Set 14 | vega de alatorre
# Processing Record 40 of Set 14 | abu samrah
# Processing Record 41 of Set 14 | nkongsamba
# Processing Record 42 of Set 14 | kozachi laheri
# Processing Record 43 of Set 14 | tabulbah
# City not found. Skipping...
# Processing Record 44 of Set 14 | moussoro
# Processing Record 45 of Set 14 | balikpapan
# Processing Record 46 of Set 14 | nisia floresta
# Processing Record 47 of Set 14 | madaripur
# Processing Record 48 of Set 14 | kishapu
# Processing Record 49 of Set 14 | sisimiut
# Processing Record 50 of Set 14 | manjeri
# Processing Record 1 of Set 15 | yankton
# Processing Record 2 of Set 15 | kalocsa
# Processing Record 3 of Set 15 | wilmington
# Processing Record 4 of Set 15 | joshimath
# Processing Record 5 of Set 15 | edd
# Processing Record 6 of Set 15 | aguimes
# Processing Record 7 of Set 15 | berdigestyakh
# Processing Record 8 of Set 15 | maun
# Processing Record 9 of Set 15 | klaipeda
# Processing Record 10 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 11 of Set 15 | ostrovnoy
# Processing Record 12 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 13 of Set 15 | yuzhne
# Processing Record 14 of Set 15 | kokuy
# Processing Record 15 of Set 15 | sharjah
# Processing Record 16 of Set 15 | herzberg
# Processing Record 17 of Set 15 | valleyview
# Processing Record 18 of Set 15 | samagaltay
# Processing Record 19 of Set 15 | tocopilla
# Processing Record 20 of Set 15 | sergeyevka
# Processing Record 21 of Set 15 | pochutla
# Processing Record 22 of Set 15 | boa vista
# Processing Record 23 of Set 15 | manono
# Processing Record 24 of Set 15 | thio
# Processing Record 25 of Set 15 | mangrol
# Processing Record 26 of Set 15 | mbanza-ngungu
# Processing Record 27 of Set 15 | lethem
# Processing Record 28 of Set 15 | cap malheureux
# Processing Record 29 of Set 15 | tezu
# Processing Record 30 of Set 15 | varna
# Processing Record 31 of Set 15 | riyadh
# Processing Record 32 of Set 15 | curup
# Processing Record 33 of Set 15 | xichang
# Processing Record 34 of Set 15 | holstebro
# Processing Record 35 of Set 15 | aklavik
# Processing Record 36 of Set 15 | los llanos de aridane
# Processing Record 37 of Set 15 | shostka
# Processing Record 38 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 15 | paramonga
# Processing Record 40 of Set 15 | okato
# Processing Record 41 of Set 15 | cuenca
# Processing Record 42 of Set 15 | sangueya
# Processing Record 43 of Set 15 | verkhnyaya inta
# Processing Record 44 of Set 15 | bucerias
# Processing Record 45 of Set 15 | bilma
# Processing Record 46 of Set 15 | yuncheng
# Processing Record 47 of Set 15 | pokhara
# Processing Record 48 of Set 15 | uklana mandi
# Processing Record 49 of Set 15 | luanda
# Processing Record 50 of Set 15 | santiago de cao
# Processing Record 1 of Set 16 | tabou
# Processing Record 2 of Set 16 | nieuw amsterdam
# Processing Record 3 of Set 16 | savannah bight
# Processing Record 4 of Set 16 | sinnamary
# Processing Record 5 of Set 16 | haapiti
# Processing Record 6 of Set 16 | dipkarpaz
# City not found. Skipping...
# Processing Record 7 of Set 16 | slavonski brod
# Processing Record 8 of Set 16 | almunecar
# Processing Record 9 of Set 16 | san nicolas
# Processing Record 10 of Set 16 | yeniseysk
# Processing Record 11 of Set 16 | kyaiklat
# Processing Record 12 of Set 16 | sciacca
# Processing Record 13 of Set 16 | carson city
# Processing Record 14 of Set 16 | saint-louis
# Processing Record 15 of Set 16 | turkistan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ribeira Grande  38.5167  -28.7000     66.60        88          40
# 1     Yellowknife  62.4560 -114.3525     -1.59        78          75
# 2       Busselton -33.6500  115.3333     54.05        65          99
# 3         Rikitea -23.1203 -134.9692     74.82        69           1
# 4          Albany  42.6001  -73.9662     40.23        50          71
# 5          Padang  -0.9492  100.3543     76.73        80         100
# 6        Mirassol -20.8192  -49.5211     92.88        26          20
# 7          Touros  -5.1989  -35.4608     83.30        74          88
# 8            Mana   5.6592  -53.7767     82.51        74          51
# 9         Mataura -46.1927  168.8643     51.08        71          19
#
#    Wind Speed       Description Country
# 0       17.27  scattered clouds      PT
# 1       14.97     broken clouds      CA
# 2        8.95   overcast clouds      AU
# 3       10.51         clear sky      PF
# 4        1.99     broken clouds      US
# 5        3.20   overcast clouds      ID
# 6        6.91        few clouds      BR
# 7       15.50   overcast clouds      BR
# 8        9.60     broken clouds      GF
# 9        2.75        few clouds      NZ

# %%
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ribeira Grande      PT  38.5167  -28.7000     66.60        88          40
# 1     Yellowknife      CA  62.4560 -114.3525     -1.59        78          75
# 2       Busselton      AU -33.6500  115.3333     54.05        65          99
# 3         Rikitea      PF -23.1203 -134.9692     74.82        69           1
# 4          Albany      US  42.6001  -73.9662     40.23        50          71
# 5          Padang      ID  -0.9492  100.3543     76.73        80         100
# 6        Mirassol      BR -20.8192  -49.5211     92.88        26          20
# 7          Touros      BR  -5.1989  -35.4608     83.30        74          88
# 8            Mana      GF   5.6592  -53.7767     82.51        74          51
# 9         Mataura      NZ -46.1927  168.8643     51.08        71          19
#
#    Wind Speed       Description
# 0       17.27  scattered clouds
# 1       14.97     broken clouds
# 2        8.95   overcast clouds
# 3       10.51         clear sky
# 4        1.99     broken clouds
# 5        3.20   overcast clouds
# 6        6.91        few clouds
# 7       15.50   overcast clouds
# 8        9.60     broken clouds
# 9        2.75        few clouds

# %%
# Create output CSV
output_data_file = 'WeatherPy_Database.csv'
# Export the City_Data into CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')
